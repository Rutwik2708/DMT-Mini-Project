# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('C:\\Users\\Dell\\Desktop\\DMT Mini Project\\loan dataset.csv')
data.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'minority', 'sex', 'ZIP', 'rent',
#        'education', 'age', 'income', 'loan_size', 'payment_timing',
#        'job_stability', 'year', 'default', 'occupation'],
#       dtype='object')

# %%
df = data.drop('Unnamed: 0', 1)

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'minority', 'sex', 'ZIP', 'rent', 'education', 'age',
#        'income', 'loan_size', 'payment_timing', 'job_stability', 'year',
#        'default', 'occupation'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1      0
# minority          0
# sex               0
# ZIP               0
# rent              0
# education         0
# age               0
# income            0
# loan_size         0
# payment_timing    0
# job_stability     0
# year              0
# default           0
# occupation        0
# dtype: int64

# %%
import seaborn as sns
cor= df.corr()
ax = sns.heatmap(cor, cmap="Greens")

# %%
df['default'].value_counts()
# Out:
# False    136055
# True      23945
# Name: default, dtype: int64

# %%
sns.scatterplot(x=df['education'], y=df['income'])

# %%
df['label'] = ['1' if star == True else '0' for star in data['default']];
df
# Out:
#         Unnamed: 0.1  minority  sex     ZIP  rent  education        age  \
# 0                  0         1    0  MT04PA     1  51.265723  25.710781
# 1                  1         0    0  MT04PA     0  58.882849  39.689510
# 2                  2         0    0  MT04PA     0  56.504545  25.847324
# 3                  3         1    0  MT04PA     1  47.074111  26.381109
# 4                  4         1    0  MT04PA     1  48.916960  18.779902
# ...              ...       ...  ...     ...   ...        ...        ...
# 159995          7995         0    1  MT12RA     0  52.870499  20.013553
# 159996          7996         0    1  MT12RA     0  47.928770  49.105852
# 159997          7997         1    1  MT12RA     0  39.637948  65.372574
# 159998          7998         1    1  MT12RA     0  53.646738  18.154397
# 159999          7999         1    1  MT12RA     0  44.806230  66.549711
#
#                income    loan_size  payment_timing  job_stability  year  \
# 0       166455.209729  8064.951996        3.874735      43.764963    30
# 1       216752.885725  7166.701945        3.809001      46.903977    30
# 2       183764.480788  3322.045258        3.497214      63.453467    30
# 3       154057.004978    15.223904        3.535370      56.243840    30
# 4       143463.038107  7860.534547        3.663330      49.884194    30
# ...               ...          ...             ...            ...   ...
# 159995  158421.675519  1325.315567        3.561940      98.012059    49
# 159996  186633.585503  4470.150590        3.364815      81.323488    49
# 159997  165690.696544  8062.143776        3.880407     111.569970    49
# 159998  155517.216520  8873.519133        3.533323     110.030919    49
# 159999  188094.275956  6130.279590        1.317479      94.173887    49
#
#         default occupation label
# 0          True     MZ10CD     1
# 1         False     MZ01CD     0
# 2         False     MZ01CD     0
# 3         False     MZ10CD     0
# 4         False     MZ10CD     0
# ...         ...        ...   ...
# 159995    False     MZ01CD     0
# 159996    False     MZ01CD     0
# 159997    False     MZ11CD     0
# 159998    False     MZ11CD     0
# 159999    False     MZ11CD     0
#
# [160000 rows x 15 columns]

# %%
cols = [0,3,11,12,13]
df.drop(df.columns[cols],axis=1,inplace=True)
df.head()
# Out:
#    minority  sex  rent  education        age         income    loan_size  \
# 0         1    0     1  51.265723  25.710781  166455.209729  8064.951996
# 1         0    0     0  58.882849  39.689510  216752.885725  7166.701945
# 2         0    0     0  56.504545  25.847324  183764.480788  3322.045258
# 3         1    0     1  47.074111  26.381109  154057.004978    15.223904
# 4         1    0     1  48.916960  18.779902  143463.038107  7860.534547
#
#    payment_timing  job_stability label
# 0        3.874735      43.764963     1
# 1        3.809001      46.903977     0
# 2        3.497214      63.453467     0
# 3        3.535370      56.243840     0
# 4        3.663330      49.884194     0

# %%
df.columns
# Out:
# Index(['minority', 'sex', 'rent', 'education', 'age', 'income', 'loan_size',
#        'payment_timing', 'job_stability', 'label'],
#       dtype='object')

# %%
df
# Out:
#         minority  sex  rent  education        age         income    loan_size  \
# 0              1    0     1  51.265723  25.710781  166455.209729  8064.951996
# 1              0    0     0  58.882849  39.689510  216752.885725  7166.701945
# 2              0    0     0  56.504545  25.847324  183764.480788  3322.045258
# 3              1    0     1  47.074111  26.381109  154057.004978    15.223904
# 4              1    0     1  48.916960  18.779902  143463.038107  7860.534547
# ...          ...  ...   ...        ...        ...            ...          ...
# 159995         0    1     0  52.870499  20.013553  158421.675519  1325.315567
# 159996         0    1     0  47.928770  49.105852  186633.585503  4470.150590
# 159997         1    1     0  39.637948  65.372574  165690.696544  8062.143776
# 159998         1    1     0  53.646738  18.154397  155517.216520  8873.519133
# 159999         1    1     0  44.806230  66.549711  188094.275956  6130.279590
#
#         payment_timing  job_stability label
# 0             3.874735      43.764963     1
# 1             3.809001      46.903977     0
# 2             3.497214      63.453467     0
# 3             3.535370      56.243840     0
# 4             3.663330      49.884194     0
# ...                ...            ...   ...
# 159995        3.561940      98.012059     0
# 159996        3.364815      81.323488     0
# 159997        3.880407     111.569970     0
# 159998        3.533323     110.030919     0
# 159999        1.317479      94.173887     0
#
# [160000 rows x 10 columns]

# %%
y=df.label
x=df.drop('label',axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression as lm
model=lm().fit(x_train,y_train)
predictions=model.predict(x_test)
import matplotlib.pyplot as plt
plt.scatter(y_test,predictions)

# %%
from sklearn.linear_model import LogisticRegression

# instantiate the model (using the default parameters)
logreg = LogisticRegression()

# fit the model with data
logreg.fit(x_train,y_train)

#
y_pred=logreg.predict(x_test)

# %%
#from sklearn.metrics import confusion_matrix, classification_report
#print(confusion_matrix(y_test, predictions))
#print('\n')
#print(classification_report(y_test, predictions))
#model.score(X,Y)

# %%
from sklearn import metrics
print('Accuracy: ',metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy:  0.94075

# %%
from sklearn import svm
clf = svm.SVC(kernel='linear')
clf.fit(x_train, y_train)

#Predict the values using learned model using X-test set
y_pred = clf.predict(x_test)

# %%
from sklearn import metrics

# Model Accuracy: how often is the classifier correct?

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
